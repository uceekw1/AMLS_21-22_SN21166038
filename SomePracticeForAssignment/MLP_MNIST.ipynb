# %%
import tensorflow
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical

# %%
# Configuration options
feature_vector_length = 784
num_classes = 10

# %%
# Load the data
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()

# Visualize one sample
#import matplotlib.pyplot as plt
#plt.imshow(X_train[0], cmap='Greys')
#plt.show()

# Reshape the data - MLPs do not understand such things as '2D'.
# Reshape to 28 x 28 pixels = 784 features
X_train = X_train.reshape(X_train.shape[0], feature_vector_length)
X_test = X_test.reshape(X_test.shape[0], feature_vector_length)
#print(X_train.shape)

# Convert into greyscale
X_train = X_train.astype('float32')
#print(X_train[0])
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255
#print(X_train[0])

# Convert target classes to categorical ones
Y_train = to_categorical(Y_train, num_classes)
Y_test = to_categorical(Y_test, num_classes)

# %%
# Set the input shape
input_shape = (feature_vector_length,)
print(f'Feature shape: {input_shape}')

# Create the model
model = Sequential()
model.add(Dense(350, input_shape=input_shape, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))
# Out:
# Feature shape: (784,)
# 2021-12-10 16:50:45.204139: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-12-10 16:50:45.206310: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 8. Tune using inter_op_parallelism_threads for best performance.

# %%
# Configure the model and start training
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train, Y_train, epochs=10, batch_size=250, verbose=1, validation_split=0.2)
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/10
# 48000/48000 [==============================] - 3s 58us/sample - loss: 0.3886 - accuracy: 0.8894 - val_loss: 0.1755 - val_accuracy: 0.9499
# Epoch 2/10
# 48000/48000 [==============================] - 2s 39us/sample - loss: 0.1483 - accuracy: 0.9564 - val_loss: 0.1313 - val_accuracy: 0.9626
# Epoch 3/10
# 48000/48000 [==============================] - 2s 40us/sample - loss: 0.0986 - accuracy: 0.9709 - val_loss: 0.1079 - val_accuracy: 0.9688
# Epoch 4/10
# 48000/48000 [==============================] - 2s 39us/sample - loss: 0.0719 - accuracy: 0.9790 - val_loss: 0.0939 - val_accuracy: 0.9710
# Epoch 5/10
# 48000/48000 [==============================] - 2s 39us/sample - loss: 0.0525 - accuracy: 0.9846 - val_loss: 0.0929 - val_accuracy: 0.9724
# Epoch 6/10
# 48000/48000 [==============================] - 2s 39us/sample - loss: 0.0402 - accuracy: 0.9886 - val_loss: 0.0840 - val_accuracy: 0.9754
# Epoch 7/10
# 48000/48000 [==============================] - 2s 39us/sample - loss: 0.0306 - accuracy: 0.9911 - val_loss: 0.0847 - val_accuracy: 0.9758
# Epoch 8/10
# 48000/48000 [==============================] - 2s 39us/sample - loss: 0.0234 - accuracy: 0.9939 - val_loss: 0.0799 - val_accuracy: 0.9763
# Epoch 9/10
# 48000/48000 [==============================] - 2s 39us/sample - loss: 0.0183 - accuracy: 0.9951 - val_loss: 0.0792 - val_accuracy: 0.9760
# Epoch 10/10
# 48000/48000 [==============================] - 2s 39us/sample - loss: 0.0142 - accuracy: 0.9966 - val_loss: 0.0849 - val_accuracy: 0.9761

# %%
# Test the model after training
test_results = model.evaluate(X_test, Y_test, verbose=1)
print(f'Test results - Loss: {test_results[0]} - Accuracy: {test_results[1]}%')
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# Test results - Loss: 0.06835295411202824 - Accuracy: 0.9796000123023987%
