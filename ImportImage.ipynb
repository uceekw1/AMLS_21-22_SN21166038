# %%
import pandas as pd
import numpy as np
import os
import tensorflow as tf
import cv2
from tensorflow import keras
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img=mpimg.imread("/Users/kuiwang/Documents/Applied ML Systems/FinalAssignment/dataset/image/IMAGE_0001.jpg")
plt.imshow(img)
